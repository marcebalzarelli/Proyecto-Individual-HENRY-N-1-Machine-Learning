# %% [markdown]
# <a href="https://colab.research.google.com/github/marcebalzarelli/Proyecto-Individual-HENRY-N-1-Machine-Learning/blob/main/ETL%20/%20df_2000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta_archivo = '/content/drive/MyDrive/df_final_limpio.csv'
df= pd.read_csv(ruta_archivo)

# %%
df.head(3)
# Out:
#       id      budget                              genres  popularity  \
# 0    862  30000000.0   ['Animation', 'Comedy', 'Family']   21.946943
# 1   8844  65000000.0  ['Adventure', 'Fantasy', 'Family']   17.015539
# 2  15602         0.0               ['Romance', 'Comedy']   11.712900
#
#   release_date      revenue             title  vote_average  vote_count  \
# 0   1995-10-30  373554033.0         Toy Story           7.7      5415.0
# 1   1995-12-15  262797249.0           Jumanji           6.9      2413.0
# 2   1995-12-22          0.0  Grumpier Old Men           6.5        92.0
#
#    release_year     return DiaSemana        Mes  \
# 0          1995  12.451801     Lunes    Octubre
# 1          1995   4.043035   Viernes  Diciembre
# 2          1995   0.000000   Viernes  Diciembre
#
#                                                 cast  \
# 0  ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim...
# 1  ['Robin Williams', 'Jonathan Hyde', 'Kirsten D...
# ...

# %%
# Obtengo 2000 filas al azar
df_2000 = df.sample(n=2000, random_state=42)  # aplico random_state

# Recorto el dataframe original para quedarme con las 2000 filas seleccionadas
df_recortado = df_2000.copy()

# %%
df_recortado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 5567 to 20228
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            2000 non-null   int64
#  1   budget        2000 non-null   float64
#  2   genres        1914 non-null   object
#  3   popularity    2000 non-null   float64
#  4   release_date  2000 non-null   object
#  5   revenue       2000 non-null   float64
#  6   title         2000 non-null   object
#  7   vote_average  2000 non-null   float64
#  8   vote_count    2000 non-null   float64
#  9   release_year  2000 non-null   int64
#  10  return        2000 non-null   float64
#  11  DiaSemana     2000 non-null   object
#  12  Mes           2000 non-null   object
#  13  cast          2000 non-null   object
#  14  crew          2000 non-null   object
# dtypes: float64(6), int64(2), object(7)
# memory usage: 250.0+ KB

# %%
df_recortado
# Out:
#            id     budget                                        genres  \
# 5567    41280  2800000.0                         ['Romance', 'Comedy']
# 17126   68412        0.0                                     ['Drama']
# 42355  345916        0.0                                     ['Drama']
# 18806   84203  3000000.0                                    ['Comedy']
# 22098  220724        0.0               ['Fantasy', 'Action', 'Comedy']
# ...       ...        ...                                           ...
# 15013   25551        0.0                ['Crime', 'Drama', 'Thriller']
# 41873   78475        0.0                                    ['Comedy']
# 36198  205588        0.0                                  ['Thriller']
# 1422   102878        0.0                                     ['Drama']
# 20228   25272        0.0  ['Action', 'Thriller', 'Mystery', 'Foreign']
#
#        popularity release_date     revenue                 title  \
# ...

# %%
# Guardo el df de 2000 filas

df_recortado.to_csv('df_2000.csv', index=False)

# %%
#Guardo df de 2000 filas
df_recortado.to_csv('/content/drive/MyDrive/df_2000.csv', index=False)
